# %%
import sys; print(sys.executable)

# %%
import pandas as pd
pd.set_option("display.max_colwidth", 120)

df = pd.read_csv("../data/raw/marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv")
print(df.shape)
print(list(df.columns))
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv (3.10.6.final.0) (Python 3.10.6)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
